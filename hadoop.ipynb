# %%
# install java
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
#Créer une variable de JAVA_HOME
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

# %%
#download HADOOP 
# !wget https://archive.apache.org/dist/hadoop/common/hadoop-3.3.0/hadoop-3.3.0.tar.gz
#extract ficher 
# !tar -xzvf hadoop-3.3.0.tar.gz
#Copiez le fichier Hadoop à user/local
# !cp -r hadoop-3.3.0/ /usr/local/
#Trouvez le chemin Java par défaut
# !readlink -f /usr/bin/java | sed "s:bin/java::"
#run Hadoop
# !/usr/local/hadoop-3.3.0/bin/hadoop
#Créer un dossier d'entrée pour l'exercice de démonstration
# !mkdir ~/testin
#Copiez des exemples de fichiers dans le dossier d'entrée
# !cp /usr/local/hadoop-3.3.0/etc/hadoop/*.xml ~/testin
#Vérifiez que les fichiers ont été copiés avec succès dans le dossier d'entrée
# !ls ~/testin
#Exécutez le programme d'exemple MapReduce
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.0.jar grep ~/testin ~/testout 'allowed[.]*'

# %%
#Télécharger et extraire 20 newsgroup dataset
# !wget http://qwone.com/~jason/20Newsgroups/20news-18828.tar.gz
# !tar -xzvf 20news-18828.tar.gz

# %%
#donner les droit rwx a l'utilisateur pour les fichers mapper.py & reducer.py
# !chmod u+rwx /content/mapper.py
# !chmod u+rwx /content/reducer.py

# %%
#Exécutez le programme de MapReduce
# !/usr/local/hadoop-3.3.0/bin/hadoop jar /usr/local/hadoop-3.3.0/share/hadoop/tools/lib/hadoop-streaming-3.3.0.jar -input /content/20news-18828/alt.atheism/ -output ~/tryout -file /content/mapper.py  -file /content/reducer.py  -mapper 'python mapper.py'  -reducer 'python reducer.py'
